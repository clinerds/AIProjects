# %% [markdown]
# ## RAG System Using Llama2 With Hugging Face

# %%
# !pip install pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 799.8 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 51.9 MB/s eta 0:00:00

# %%
## Embedding
# !pip install install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install llama_index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.7 MB/s eta 0:00:00
# ...

# %%
# !pip install llama-index-llms-huggingface

from llama_index.core import VectorStoreIndex,SimpleDirectoryReader,ServiceContext
from llama_index.llms.huggingface import HuggingFaceLLM, HuggingFaceInferenceAPI
from llama_index.core.prompts.prompts import SimpleInputPrompt
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_fields.py:160: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
documents=SimpleDirectoryReader("./content/").load_data()
documents
# Out:
# [Document(id_='85f3620e-ccb9-47dc-ba22-2efb5fd7286f', embedding=None, metadata={'page_label': '1', 'file_name': 'economy.pdf', 'file_path': '/content/content/economy.pdf', 'file_type': 'application/pdf', 'file_size': 108245, 'creation_date': '2024-06-01', 'last_modified_date': '2024-06-01'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='The Economy of Attention - Understanding Its\nSignificance in the Digital Age\n#Reports  #TheAttentionEconomy  #DopamineReceptorsFried  #StrivingForAttention\nResearch and Dataset by: MR. Moon And Mohd T alib AKA Samael\nDate: 02-10-2023\nAbstract:\nThis report delves deep into the concept of attention as a valuable resource in the digital age. It\nexplores the evolution of social media, the impact of constant distrac
# ...

# %%
system_prompt="""
You are a Q&A assistant. Your goal is to answer questions as
accurately as possible based on the instructions and context provided.
"""
## Default format supportable by LLama2
query_wrapper_prompt=SimpleInputPrompt("<|USER|>{query_str}<|ASSISTANT|>")

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !huggingface-cli whoami
# Out:
# Samael667

# %%
from huggingface_hub import login
login(token='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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# import torch

# llm = HuggingFaceLLM(
#     context_window=4096,
#     max_new_tokens=256,
#     generate_kwargs={"temperature": 0.0, "do_sample": False},
#     system_prompt=system_prompt,
#     query_wrapper_prompt=query_wrapper_prompt,
#     tokenizer_name="mistralai/Mistral-7B-Instruct-v0.2",
#     model_name="mistralai/Mistral-7B-Instruct-v0.2",
#     device_map="auto",
#     # uncomment this if using CUDA to reduce memory usage
#     model_kwargs={"torch_dtype": torch.float16 , "load_in_8bit":True}
# )
# Out:
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
#remotly run via inference trial

llm = HuggingFaceInferenceAPI(
    model_name="mistralai/Mistral-7B-Instruct-v0.2", token='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'
)

# %%
# !pip install -U langchain-community
# !pip install llama-index-embeddings-langchain
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index.core import ServiceContext
from llama_index.embeddings.langchain import LangchainEmbedding


embed_model=LangchainEmbedding(
    HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2"))
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# service_context=ServiceContext.from_defaults(
#     chunk_size=1024,
#     llm=llm,
#     embed_model=embed_model
# )
from llama_index.core import Settings
from llama_index.core.node_parser import SentenceSplitter
Settings.llm = llm
Settings.node_parser =  SentenceSplitter(chunk_size=1024)
Settings.embed_model = embed_model

# %%
service_context
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-eb66aba03005> in <cell line: 1>()
# ----> 1 service_context
#
# NameError: name 'service_context' is not defined

# %%
index=VectorStoreIndex.from_documents(documents,service_context=service_context)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-56a080b81fa1> in <cell line: 1>()
# ----> 1 index=VectorStoreIndex.from_documents(documents,service_context=service_context)
#
# NameError: name 'service_context' is not defined

# %%
#steps after service context migration - using new method settings

# %%
index = VectorStoreIndex.from_documents(
    documents, embed_model=embed_model,
)

# %%
index

# %%
query_engine=index.as_query_engine()

# %%
## query for llm as an INference API

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
response=query_engine.query("summarize economy of attention")
print(response)
# Out:
# The Economy of Attention refers to the ecosystem where attention is the primary currency, and individuals, organizations, and entities compete for a share of this valuable resource. In the digital age, attention has transformed from an intangible aspect of human cognition into a tangible and marketable commodity. The significance of attention lies in its ability to capture our momentary focus and influence our thoughts, behaviors, and decision-making processes. Understanding how attention is harnessed and wielded is crucial to comprehending the dynamics of the modern world. This report delves deeper into the concept of attention as a commodity, exploring its economic implications and the ways individuals and organizations seek to control and exploit it. It also discusses the rise of rage-bait content and its implications for society, and provides insights into the potential consequences of our society's obsession with attention and suggests ways to regain control over our attention.

# %%
response=query_engine.query("who are you?")
print(response)
# Out:
#  I am an assistant designed to help answer queries based on textual information. I don't have personal experiences or emotions, but I can process and analyze text to provide relevant and accurate responses. In the context provided, I am here to help answer queries related to the text in the economy.pdf file.

# %%
response=query_engine.query("Tell me a quote by david")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
print(response)
# Out:
# One of the quotes by David from the context is: "Love is just a Survival mechanism for humans, to continue breeding."

# %%
response=query_engine.query("who is david?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
print(response)
# Out:
# David is an individual whose thoughts and reflections are documented in the provided text excerpts. He expresses various perspectives on life, love, family, and existence. Some of his statements suggest a sense of disillusionment, introspection, and a non-conformist attitude towards societal norms. He also seems to have a complex relationship with the concept of love and the human condition.

# %%
response=query_engine.query("who did the research for the economy of attention?")
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# MR. Moon And Mohd T alib AKA Samael conducted the research for the economy of attention as per the provided report.

# %%
response=query_engine.query("tell me about the economy of attention? also tell me who wrote it and when")
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The Economy of Attention is a concept that refers to the ecosystem where attention is the primary currency, and individuals, organizations, and entities vie for a share of this precious resource. The term has gained significance in the digital age due to the constant bombardment of stimuli and information overload. This report on the Economy of Attention was written by MR. Moon and Mohd T alib AKA Samael, and it was published on 02-10-2023. The report delves deep into the attention economy, providing an in-depth analysis of its various facets and implications, including the evolution of social media platforms, the impact of constant distraction, the exploitation of attention by corporations, and the rise of rage-bait content. Additionally, it offers insights into the consequences of living in an attention-driven society and suggests potential solutions for individuals to regain control over their attention.

# %%
response=query_engine.query("based on the economy of attention report, guess the personality and mental well being of mohd talib")
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Based on the provided context, Mohd Talib appears to be an introspective and philosophical individual who values authenticity and self-expression. He seems to have experienced a significant transformation in his personality and is currently trying to regain control and create a new one. The quotes suggest a deep understanding of life's complexities and a questioning of societal norms. However, there are also indications of struggle and a sense of losing control. It's important to note that the context does not provide enough information to definitively assess Mohd Talib's mental well-being.

# %%
# !curl ifconfig.me
# Out:
# 34.125.185.139

# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn

# %%
# from fastapi import FastAPI
# import nest_asyncio
# from pyngrok import ngrok
# import uvicorn

# app = FastAPI()

# @app.get('/index')
# async def home():
#   return "Hello World"

# ngrok.set_auth_token("2hHMC3auP4XmtbjMjeyxvVwWuFg_4yHNFqS3nAoEJPic8nUtu")
# ngrok_tunnel = ngrok.connect(8000)
# print('Public URL:', ngrok_tunnel.public_url)
# nest_asyncio.apply()
# uvicorn.run(app, port=8000)

# %%
from fastapi import FastAPI
import nest_asyncio
from pyngrok import ngrok
import uvicorn

app = FastAPI()

@app.post("/ask")
async def prompt(req: Request):
   body = await req.json()
   prompt = body['question']
   api_response = query_engine.query(prompt)
   return {"answer": response}

ngrok.set_auth_token("2hHMC3auP4XmtbjMjeyxvVwWuFg_4yHNFqS3nAoEJPic8nUtu")
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79c6d821bfca> in <cell line: 1>()
# ----> 1 @app.post("/ask")
#       2 async def prompt(req: Request):
#       3    body = await req.json()
#       4    prompt = body['question']
#       5    api_response = query_engine.query(prompt)
#
# NameError: name 'app' is not defined
